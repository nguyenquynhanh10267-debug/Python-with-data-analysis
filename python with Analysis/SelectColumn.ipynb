# %%
import pandas as pd

# %%
# reading the csv file
df = pd.read_csv(r'D:\py with DA\Python-with-data-analysis\dataset\StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1 Selecting one column

# %% [markdown]
# ## 1.1 Syntax 1

# %%
# select a column with []
df['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: str

# %%
# check out the data type of a column
type( df['gender'])
# Out:
# pandas.Series

# %%
# series: attributes and methods
df['gender'].index
df['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: str

# %% [markdown]
# # 1.2 Syntax 2

# %%
# select a column with .
df.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: str

# %%
df.math_score
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11336\168014252.py in ?()
# ----> 1 df.math_score
#
# c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'math_score'

# %%
df['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# # 2 Selecting two or more columns

# %%
# selecting two columns using [[]]
df[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
# check out the data type of the selection
type(df[['gender', 'math score']])
# Out:
# pandas.DataFrame

# %%
# selecting two or more columns using [[]]
df[['gender', 'math score', 'writing score']]
# Out:
#      gender  math score  writing score
# 0    female          72             74
# 1    female          69             88
# 2    female          90             93
# 3      male          47             44
# 4      male          76             75
# ..      ...         ...            ...
# 995  female          88             95
# 996    male          62             55
# 997  female          59             65
# 998  female          68             77
# 999  female          77             86
#
# [1000 rows x 3 columns]

# %%
# we can't select 2 or more columns with the "."
# df.'gender', 'math' -> error

# %% [markdown]
# # 3 add new column to a data frame

# %% [markdown]
# ## 3.1 Adding a new column with a scalar value

# %%
# adding new column to dataframe
df['language score'] = 70

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # 3.2 Adding new column with array

# %%
import numpy as np

# %%
# create an array of 1000 elements
language = np.arange(0,1000)

# %%
# Adding new column to dataframe
df['language score'] = language
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# create random integer numbers [1,100]
language = np.random.randint(1,100, size = 1000)

# %%
df['language score'] = language
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# min and max
min(language)
max(language)
# Out:
# np.int32(99)

# %%
# create random float [1,100]
np.random.uniform(1,100, size = 1000)
# Out:
# array([ 3.82049789, 88.56430514, 84.36440979, 25.82223707, 57.41987713,
#        77.42916176,  1.45764559, 33.70489825, 73.90630744, 15.83024224,
#        80.35352554, 70.11534807, 39.06113453, 94.99725378, 46.61158147,
#        86.81423686, 28.81021142, 97.75947135, 57.06672336, 13.0661265 ,
#        75.26219113, 66.5249798 , 71.91571552, 61.39912151, 43.48440451,
#        91.64562438, 67.40606624, 56.4901151 , 16.22067993,  3.95189906,
#        79.61058677, 69.65169   , 27.26785467, 87.60335669, 31.35625323,
#        65.68615966, 45.07348177, 63.56331623, 40.06922242, 44.48186132,
#        51.17390356, 16.63068044, 82.93220536, 82.64459626, 23.28836992,
#        20.95406351, 17.58897765, 92.32780253, 31.60094832,  8.6222086 ,
#        88.31717573, 45.25301294, 28.80880637, 54.09915871, 75.57211634,
#        41.90103166, 35.11470103, 39.80828933, 34.63451579, 92.40343293,
#        88.86436313, 88.42313952, 73.5053643 , 67.59894441, 89.9412666 ,
# ...
